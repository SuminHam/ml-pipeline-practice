# %%
import mlflow

# %%
mlflow.set_tracking_uri('http://10.178.0.4:5000')

# %%
mlflow.get_experiment('1')
# Out:
# <Experiment: artifact_location='s3://mlflow/mlruns/1', experiment_id='1', lifecycle_stage='active', name='DELETE_TEST', tags={}>

# %%
import os

os.environ['AWS_ACCESS_KEY_ID'] = 'mlflow_admin'
os.environ['AWS_SECRET_ACCESS_KEY'] = 'mlflow_admin'
os.environ['MLFLOW_S3_ENDPOINT_URL'] = 'http://10.178.0.4:9000'

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
params = {
    'n_estimators': 100,
    'max_depth': 4
}
metrics = {
    'accuracy': 0.8
}

with mlflow.start_run():
    mlflow.log_params(params)
    mlflow.log_metrics(metrics)
    mlflow.sklearn.log_model(model,'model')
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/mle_course/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/miniconda3/envs/mle_course/lib/python3.11/site-packages/urllib3/connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/miniconda3/envs/mle_course/lib/python3.11/site-packages/urllib3/connection.py:653, in HTTPSConnection.connect(self)
# ...
